# %%
from phySyncFirmata import ArduinoNano
import phySyncFirmata
import time

# %%
PORT = ArduinoNano.AUTODETECT
board = ArduinoNano(PORT)
# setting port for Arduino

board.samplingOn()

# %%
t = 0.1
frequency = 0.1

# %%
String_to_be_changed_into_Morse = '''Hello Mrityunjai, this sentence has all english alphabets @ The quick brown fox jumps over a lazy dog.
'''

# %%
Buzzer = board.get_pin('d:5:p')

# %%
for element in String_to_be_changed_into_Morse.upper():
    if element == ' ':
        print(' ')
        board.pass_time(2*t)
        
    if element == 'A':
        print('A: .-')
        Buzzer.write(frequency)
        board.pass_time(t)
        Buzzer.write(0)
        board.pass_time(t)
        Buzzer.write(frequency)
        board.pass_time(3*t)
        Buzzer.write(0)
        board.pass_time(3*t)
        
    elif element == 'B':
        print('B: -...')
        Buzzer.write(frequency)
        board.pass_time(3*t)
        Buzzer.write(0)
        board.pass_time(t)
        Buzzer.write(frequency)
        board.pass_time(t)
        Buzzer.write(0)
        board.pass_time(t)
        Buzzer.write(frequency)
        board.pass_time(t)
        Buzzer.write(0)
        board.pass_time(t)
        Buzzer.write(frequency)
        board.pass_time(t)
        Buzzer.write(0)
        board.pass_time(3*t)
    elif element == 'C':
        print('C: -.-.')
        Buzzer.write(frequency)
        board.pass_time(3*t)
        Buzzer.write(0)
        board.pass_time(t)
        Buzzer.write(frequency)
        board.pass_time(t)
        Buzzer.write(0)
        board.pass_time(t)
        Buzzer.write(frequency)
        board.pass_time(3*t)
        Buzzer.write(0)
        board.pass_time(t)
        Buzzer.write(frequency)
        board.pass_time(t)
        Buzzer.write(0)
        board.pass_time(3*t)
    elif element == 'D':
        print('D: -..')
        Buzzer.write(frequency)
        board.pass_time(3*t)
        Buzzer.write(0)
        board.pass_time(t)
        Buzzer.write(frequency)
        board.pass_time(t)
        Buzzer.write(0)
        board.pass_time(t)
        Buzzer.write(frequency)
        board.pass_time(t)
        Buzzer.write(0)
        board.pass_time(3*t)
        
    elif element == 'E':
        print('E: .')
        Buzzer.write(frequency)
        board.pass_time(t)
        Buzzer.write(0)
        board.pass_time(3*t)
        
    elif element == 'F':
        print('F: ..-.')
        Buzzer.write(frequency)
        board.pass_time(t)
        Buzzer.write(0)
        board.pass_time(t)
        Buzzer.write(frequency)
        board.pass_time(t)
        Buzzer.write(0)
        board.pass_time(t)
        Buzzer.write(frequency)
        board.pass_time(3*t)
        Buzzer.write(0)
        board.pass_time(t)
        Buzzer.write(frequency)
        board.pass_time(t)
        Buzzer.write(0)
        board.pass_time(3*t)
        
    elif element == 'G':
        print('G: --.')
        Buzzer.write(frequency)
        board.pass_time(3*t)
        Buzzer.write(0)
        board.pass_time(t)
        Buzzer.write(frequency)
        board.pass_time(3*t)
        Buzzer.write(0)
        board.pass_time(t)
        Buzzer.write(frequency)
        board.pass_time(t)
        Buzzer.write(0)
        board.pass_time(3*t)
        
    elif element == 'H':
        print('H: ....')
        Buzzer.write(frequency)
        board.pass_time(t)
        Buzzer.write(0)
        board.pass_time(t)
        Buzzer.write(frequency)
        board.pass_time(t)
        Buzzer.write(0)
        board.pass_time(t)
        Buzzer.write(frequency)
        board.pass_time(t)
        Buzzer.write(0)
        board.pass_time(t)
        Buzzer.write(frequency)
        board.pass_time(t)
        Buzzer.write(0)
        board.pass_time(3*t)
        
    elif element == 'I':
        print('I: ..')
        Buzzer.write(frequency)
        board.pass_time(t)
        Buzzer.write(0)
        board.pass_time(t)
        Buzzer.write(frequency)
        board.pass_time(t)
        Buzzer.write(0)
        board.pass_time(3*t)
        
    elif element == 'J':
        print('J: .---')
        Buzzer.write(frequency)
        board.pass_time(t)
        Buzzer.write(0)
        board.pass_time(t)
        Buzzer.write(frequency)
        board.pass_time(3*t)
        Buzzer.write(0)
        board.pass_time(t)
        Buzzer.write(frequency)
        board.pass_time(3*t)
        Buzzer.write(0)
        board.pass_time(t)
        Buzzer.write(frequency)
        board.pass_time(3*t)
        Buzzer.write(0)
        board.pass_time(3*t)
        
    elif element == 'K':
        print('K: -.-')
        Buzzer.write(frequency)
        board.pass_time(3*t)
        Buzzer.write(0)
        board.pass_time(t)
        Buzzer.write(frequency)
        board.pass_time(t)
        Buzzer.write(0)
        board.pass_time(t)
        Buzzer.write(frequency)
        board.pass_time(3*t)
        Buzzer.write(0)
        board.pass_time(3*t)
        
    elif element == 'L':
        print('L: .-..')
        Buzzer.write(frequency)
        board.pass_time(t)
        Buzzer.write(0)
        board.pass_time(t)
        Buzzer.write(frequency)
        board.pass_time(3*t)
        Buzzer.write(0)
        board.pass_time(t)
        Buzzer.write(frequency)
        board.pass_time(t)
        Buzzer.write(0)
        board.pass_time(t)
        Buzzer.write(frequency)
        board.pass_time(t)
        Buzzer.write(0)
        board.pass_time(3*t)
        
    elif element == 'M':
        print('M: --')
        Buzzer.write(frequency)
        board.pass_time(3*t)
        Buzzer.write(0)
        board.pass_time(t)
        Buzzer.write(frequency)
        board.pass_time(3*t)
        Buzzer.write(0)
        board.pass_time(3*t)
        
    elif element == 'N':
        print('N: -.')
        Buzzer.write(frequency)
        board.pass_time(3*t)
        Buzzer.write(0)
        board.pass_time(t)
        Buzzer.write(frequency)
        board.pass_time(t)
        Buzzer.write(0)
        board.pass_time(3*t)
        
    elif element == 'O':
        print('O: ---')
        Buzzer.write(frequency)
        board.pass_time(3*t)
        Buzzer.write(0)
        board.pass_time(t)
        Buzzer.write(frequency)
        board.pass_time(3*t)
        Buzzer.write(0)
        board.pass_time(t)
        Buzzer.write(frequency)
        board.pass_time(3*t)
        Buzzer.write(0)
        board.pass_time(3*t)
        
    elif element == 'P':
        print('P: .--.')
        Buzzer.write(frequency)
        board.pass_time(t)
        Buzzer.write(0)
        board.pass_time(t)
        Buzzer.write(frequency)
        board.pass_time(3*t)
        Buzzer.write(0)
        board.pass_time(t)
        Buzzer.write(frequency)
        board.pass_time(3*t)
        Buzzer.write(0)
        board.pass_time(t)
        Buzzer.write(frequency)
        board.pass_time(t)
        Buzzer.write(0)
        board.pass_time(3*t)
    elif element == 'Q':
        print('Q: --.-')
        Buzzer.write(frequency)
        board.pass_time(3*t)
        Buzzer.write(0)
        board.pass_time(t)
        Buzzer.write(frequency)
        board.pass_time(3*t)
        Buzzer.write(0)
        board.pass_time(t)
        Buzzer.write(frequency)
        board.pass_time(t)
        Buzzer.write(0)
        board.pass_time(t)
        Buzzer.write(frequency)
        board.pass_time(3*t)
        Buzzer.write(0)
        board.pass_time(3*t)
        
    elif element == 'R':
        print('R: .-.')
        Buzzer.write(frequency)
        board.pass_time(t)
        Buzzer.write(0)
        board.pass_time(t)
        Buzzer.write(frequency)
        board.pass_time(3*t)
        Buzzer.write(0)
        board.pass_time(t)
        Buzzer.write(frequency)
        board.pass_time(t)
        Buzzer.write(0)
        board.pass_time(3*t)
        
    elif element == 'S':
        print('S: ...')
        Buzzer.write(frequency)
        board.pass_time(t)
        Buzzer.write(0)
        board.pass_time(t)
        Buzzer.write(frequency)
        board.pass_time(t)
        Buzzer.write(0)
        board.pass_time(t)
        Buzzer.write(frequency)
        board.pass_time(t)
        Buzzer.write(0)
        board.pass_time(3*t)
        
    elif element == 'T':
        print('T: -')
        Buzzer.write(frequency)
        board.pass_time(3*t)
        Buzzer.write(0)
        board.pass_time(3*t)
        
    elif element == 'U':
        print('U: ..-')
        Buzzer.write(frequency)
        board.pass_time(t)
        Buzzer.write(0)
        board.pass_time(t)
        Buzzer.write(frequency)
        board.pass_time(t)
        Buzzer.write(0)
        board.pass_time(t)
        Buzzer.write(frequency)
        board.pass_time(3*t)
        Buzzer.write(0)
        board.pass_time(3*t)
        
    elif element == 'V':
        print('V: ...-')
        Buzzer.write(frequency)
        board.pass_time(t)
        Buzzer.write(0)
        board.pass_time(t)
        Buzzer.write(frequency)
        board.pass_time(t)
        Buzzer.write(0)
        board.pass_time(t)
        Buzzer.write(frequency)
        board.pass_time(t)
        Buzzer.write(0)
        board.pass_time(t)
        Buzzer.write(frequency)
        board.pass_time(3*t)
        Buzzer.write(0)
        board.pass_time(3*t)
        
    elif element == 'W':
        print('W: .--')
        Buzzer.write(frequency)
        board.pass_time(t)
        Buzzer.write(0)
        board.pass_time(t)
        Buzzer.write(frequency)
        board.pass_time(3*t)
        Buzzer.write(0)
        board.pass_time(t)
        Buzzer.write(frequency)
        board.pass_time(3*t)
        Buzzer.write(0)
        board.pass_time(3*t)
        
    elif element == 'X':
        print('X: -..-')
        Buzzer.write(frequency)
        board.pass_time(3*t)
        Buzzer.write(0)
        board.pass_time(t)
        Buzzer.write(frequency)
        board.pass_time(t)
        Buzzer.write(0)
        board.pass_time(t)
        Buzzer.write(frequency)
        board.pass_time(t)
        Buzzer.write(0)
        board.pass_time(t)
        Buzzer.write(frequency)
        board.pass_time(3*t)
        Buzzer.write(0)
        board.pass_time(3*t)
        
    elif element == 'Y':
        print('Y: -.--')
        Buzzer.write(frequency)
        board.pass_time(3*t)
        Buzzer.write(0)
        board.pass_time(t)
        Buzzer.write(frequency)
        board.pass_time(t)
        Buzzer.write(0)
        board.pass_time(t)
        Buzzer.write(frequency)
        board.pass_time(3*t)
        Buzzer.write(0)
        board.pass_time(t)
        Buzzer.write(frequency)
        board.pass_time(3*t)
        Buzzer.write(0)
        board.pass_time(3*t)
        
    elif element == 'Z':
        print('Z: --..')
        Buzzer.write(frequency)
        board.pass_time(3*t)
        Buzzer.write(0)
        board.pass_time(t)
        Buzzer.write(frequency)
        board.pass_time(3*t)
        Buzzer.write(0)
        board.pass_time(t)
        Buzzer.write(frequency)
        board.pass_time(t)
        Buzzer.write(0)
        board.pass_time(t)
        Buzzer.write(frequency)
        board.pass_time(t)
        Buzzer.write(0)
        board.pass_time(3*t)
        
    elif element == '.':
        print('.: .-.-.-')
        Buzzer.write(frequency)
        board.pass_time(t)
        Buzzer.write(0)
        board.pass_time(t)
        Buzzer.write(frequency)
        board.pass_time(3*t)
        Buzzer.write(0)
        board.pass_time(t)
        Buzzer.write(frequency)
        board.pass_time(t)
        Buzzer.write(0)
        board.pass_time(t)
        Buzzer.write(frequency)
        board.pass_time(3*t)
        Buzzer.write(0)
        board.pass_time(t)
        Buzzer.write(frequency)
        board.pass_time(t)
        Buzzer.write(0)
        board.pass_time(t)
        Buzzer.write(frequency)
        board.pass_time(3*t)
        Buzzer.write(0)
        board.pass_time(3*t)
        
    elif element == ',':
        print(',: --..--')
        Buzzer.write(frequency)
        board.pass_time(3*t)
        Buzzer.write(0)
        board.pass_time(t)
        Buzzer.write(frequency)
        board.pass_time(3*t)
        Buzzer.write(0)
        board.pass_time(t)
        Buzzer.write(frequency)
        board.pass_time(t)
        Buzzer.write(0)
        board.pass_time(t)
        Buzzer.write(frequency)
        board.pass_time(t)
        Buzzer.write(0)
        board.pass_time(t)
        Buzzer.write(frequency)
        board.pass_time(3*t)
        Buzzer.write(0)
        board.pass_time(t)
        Buzzer.write(frequency)
        board.pass_time(3*t)
        Buzzer.write(0)
        board.pass_time(3*t)
        
    elif element == '?':
        print('?: ..--..')
        Buzzer.write(frequency)
        board.pass_time(t)
        Buzzer.write(0)
        board.pass_time(t)
        Buzzer.write(frequency)
        board.pass_time(t)
        Buzzer.write(0)
        board.pass_time(t)
        Buzzer.write(frequency)
        board.pass_time(3*t)
        Buzzer.write(0)
        board.pass_time(t)
        Buzzer.write(frequency)
        board.pass_time(3*t)
        Buzzer.write(0)
        board.pass_time(t)
        Buzzer.write(frequency)
        board.pass_time(t)
        Buzzer.write(0)
        board.pass_time(t)
        Buzzer.write(frequency)
        board.pass_time(t)
        Buzzer.write(0)
        board.pass_time(3*t)
        
    elif element == '/':
        print('/: -..-.')
        Buzzer.write(frequency)
        board.pass_time(3*t)
        Buzzer.write(0)
        board.pass_time(t)
        Buzzer.write(frequency)
        board.pass_time(t)
        Buzzer.write(0)
        board.pass_time(t)
        Buzzer.write(frequency)
        board.pass_time(t)
        Buzzer.write(0)
        board.pass_time(t)
        Buzzer.write(frequency)
        board.pass_time(3*t)
        Buzzer.write(0)
        board.pass_time(t)
        Buzzer.write(frequency)
        board.pass_time(t)
        Buzzer.write(0)
        board.pass_time(3*t)
        
    elif element == '@':
        print('@: .--.-.')
        Buzzer.write(frequency)
        board.pass_time(t)
        Buzzer.write(0)
        board.pass_time(t)
        Buzzer.write(frequency)
        board.pass_time(3*t)
        Buzzer.write(0)
        board.pass_time(t)
        Buzzer.write(frequency)
        board.pass_time(3*t)
        Buzzer.write(0)
        board.pass_time(t)
        Buzzer.write(frequency)
        board.pass_time(t)
        Buzzer.write(0)
        board.pass_time(t)
        Buzzer.write(frequency)
        board.pass_time(3*t)
        Buzzer.write(0)
        board.pass_time(t)
        Buzzer.write(frequency)
        board.pass_time(t)
        Buzzer.write(0)
        board.pass_time(3*t)
        
    elif element == '0':
        print('0: -----')
        Buzzer.write(frequency)
        board.pass_time(3*t)
        Buzzer.write(0)
        board.pass_time(t)
        Buzzer.write(frequency)
        board.pass_time(3*t)
        Buzzer.write(0)
        board.pass_time(t)
        Buzzer.write(frequency)
        board.pass_time(3*t)
        Buzzer.write(0)
        board.pass_time(t)
        Buzzer.write(frequency)
        board.pass_time(3*t)
        Buzzer.write(0)
        board.pass_time(t)
        Buzzer.write(frequency)
        board.pass_time(3*t)
        Buzzer.write(0)
        board.pass_time(3*t)
        
    elif element == '1':
        print('1: .----')
        Buzzer.write(frequency)
        board.pass_time(t)
        Buzzer.write(0)
        board.pass_time(t)
        Buzzer.write(frequency)
        board.pass_time(3*t)
        Buzzer.write(0)
        board.pass_time(t)
        Buzzer.write(frequency)
        board.pass_time(3*t)
        Buzzer.write(0)
        board.pass_time(t)
        Buzzer.write(frequency)
        board.pass_time(3*t)
        Buzzer.write(0)
        board.pass_time(t)
        Buzzer.write(frequency)
        board.pass_time(3*t)
        Buzzer.write(0)
        board.pass_time(3*t)
        
    elif element == '2':
        print('2: ..---')
        Buzzer.write(frequency)
        board.pass_time(t)
        Buzzer.write(0)
        board.pass_time(t)
        Buzzer.write(frequency)
        board.pass_time(t)
        Buzzer.write(0)
        board.pass_time(t)
        Buzzer.write(frequency)
        board.pass_time(3*t)
        Buzzer.write(0)
        board.pass_time(t)
        Buzzer.write(frequency)
        board.pass_time(3*t)
        Buzzer.write(0)
        board.pass_time(t)
        Buzzer.write(frequency)
        board.pass_time(3*t)
        Buzzer.write(0)
        board.pass_time(3*t)
        
    elif element == '3':
        print('3: ...--')
        Buzzer.write(frequency)
        board.pass_time(t)
        Buzzer.write(0)
        board.pass_time(t)
        Buzzer.write(frequency)
        board.pass_time(t)
        Buzzer.write(0)
        board.pass_time(t)
        Buzzer.write(frequency)
        board.pass_time(t)
        Buzzer.write(0)
        board.pass_time(t)
        Buzzer.write(frequency)
        board.pass_time(3*t)
        Buzzer.write(0)
        board.pass_time(t)
        Buzzer.write(frequency)
        board.pass_time(3*t)
        Buzzer.write(0)
        board.pass_time(3*t)
        
    elif element == '4':
        print('4: ....-')
        Buzzer.write(frequency)
        board.pass_time(t)
        Buzzer.write(0)
        board.pass_time(t)
        Buzzer.write(frequency)
        board.pass_time(t)
        Buzzer.write(0)
        board.pass_time(t)
        Buzzer.write(frequency)
        board.pass_time(t)
        Buzzer.write(0)
        board.pass_time(t)
        Buzzer.write(frequency)
        board.pass_time(t)
        Buzzer.write(0)
        board.pass_time(t)
        Buzzer.write(frequency)
        board.pass_time(3*t)
        Buzzer.write(0)
        board.pass_time(3*t)
        
    elif element == '5':
        print('5: .....')
        Buzzer.write(frequency)
        board.pass_time(t)
        Buzzer.write(0)
        board.pass_time(t)
        Buzzer.write(frequency)
        board.pass_time(t)
        Buzzer.write(0)
        board.pass_time(t)
        Buzzer.write(frequency)
        board.pass_time(t)
        Buzzer.write(0)
        board.pass_time(t)
        Buzzer.write(frequency)
        board.pass_time(t)
        Buzzer.write(0)
        board.pass_time(t)
        Buzzer.write(frequency)
        board.pass_time(t)
        Buzzer.write(0)
        board.pass_time(3*t)
        
    elif element == '6':
        print('6: -....')
        Buzzer.write(frequency)
        board.pass_time(3*t)
        Buzzer.write(0)
        board.pass_time(t)
        Buzzer.write(frequency)
        board.pass_time(t)
        Buzzer.write(0)
        board.pass_time(t)
        Buzzer.write(frequency)
        board.pass_time(t)
        Buzzer.write(0)
        board.pass_time(t)
        Buzzer.write(frequency)
        board.pass_time(t)
        Buzzer.write(0)
        board.pass_time(t)
        Buzzer.write(frequency)
        board.pass_time(t)
        Buzzer.write(0)
        board.pass_time(3*t)
        
    elif element == '7':
        print('7: --...')
        Buzzer.write(frequency)
        board.pass_time(3*t)
        Buzzer.write(0)
        board.pass_time(t)
        Buzzer.write(frequency)
        board.pass_time(3*t)
        Buzzer.write(0)
        board.pass_time(t)
        Buzzer.write(frequency)
        board.pass_time(t)
        Buzzer.write(0)
        board.pass_time(t)
        Buzzer.write(frequency)
        board.pass_time(t)
        Buzzer.write(0)
        board.pass_time(t)
        Buzzer.write(frequency)
        board.pass_time(t)
        Buzzer.write(0)
        board.pass_time(3*t)
        
    elif element == '8':
        print('8: ---..')
        Buzzer.write(frequency)
        board.pass_time(3*t)
        Buzzer.write(0)
        board.pass_time(t)
        Buzzer.write(frequency)
        board.pass_time(3*t)
        Buzzer.write(0)
        board.pass_time(t)
        Buzzer.write(frequency)
        board.pass_time(3*t)
        Buzzer.write(0)
        board.pass_time(t)
        Buzzer.write(frequency)
        board.pass_time(t)
        Buzzer.write(0)
        board.pass_time(t)
        Buzzer.write(frequency)
        board.pass_time(t)
        Buzzer.write(0)
        board.pass_time(3*t)
        
    elif element == '9':
        print('9: ----.')
        Buzzer.write(frequency)
        board.pass_time(3*t)
        Buzzer.write(0)
        board.pass_time(t)
        Buzzer.write(frequency)
        board.pass_time(3*t)
        Buzzer.write(0)
        board.pass_time(t)
        Buzzer.write(frequency)
        board.pass_time(3*t)
        Buzzer.write(0)
        board.pass_time(t)
        Buzzer.write(frequency)
        board.pass_time(3*t)
        Buzzer.write(0)
        board.pass_time(t)
        Buzzer.write(frequency)
        board.pass_time(t)
        Buzzer.write(0)
        board.pass_time(3*t)
board.exit()
# Out:
# M: --
# R: .-.
# I: ..
# T: -
# Y: -.--
# U: ..-
# N: -.
# J: .---
# A: .-
# I: ..
